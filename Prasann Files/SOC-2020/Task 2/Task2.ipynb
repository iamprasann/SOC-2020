# %%
from random import seed, randint
from matplotlib import pyplot as plt

iters=[0]*500
for k in range(500):
  arr=[0]*1000
  ones=[1]
  n=0

  arr[500]=1

  while((ones[n])!=1000):
     for i in range(1000):
          if(arr[i]==1):
              if(randint(0,1)):
                  arr[abs(i-1)]=1
              else:
                  arr[(i+1)%1000]=1
     a1=randint(0,999)
     a2=randint(0,999) 
     while(a1==a2):
      a2=randint(0,999)
     a3=0
   
     a3=arr[a1]
     arr[a1]=arr[a2]
     arr[a2]=a3
  
     n=n+1

     ones.append(0)
    
     for i in range(1000):
        if(arr[i]==1):
              ones[n]=ones[n]+1
  
     for i in range(n):
       x.append(i+1)
    
  iters[k]=n

x=[1]  
for i in range(499):
    x.append(i+1)
    
plt.plot(x, iters)
plt.xlabel('run no.')
plt.ylabel('no. of iterations needed')
plt.show()

sum=0
for k in range(500):
  sum=sum+iters[k]

print(sum/500)
# Out:
# 124.992
